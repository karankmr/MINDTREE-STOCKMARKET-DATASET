# %% [markdown]
# ### Query 2.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

# %%
df = pd.read_csv("./week2.csv")

# %%
df['Date'] = df.Date.astype('datetime64')

# %%
df
# Out:
#      Unnamed: 0    Symbol Series       Date  Prev Close  Open Price  \
# 0             0  MINDTREE     EQ 2017-05-15      510.60      507.35
# 1             1  MINDTREE     EQ 2017-05-16      509.45      507.00
# 2             2  MINDTREE     EQ 2017-05-17      511.30      507.05
# 3             3  MINDTREE     EQ 2017-05-18      506.35      502.00
# 4             4  MINDTREE     EQ 2017-05-19      492.90      491.95
# 5             5  MINDTREE     EQ 2017-05-22      497.50      499.95
# 6             6  MINDTREE     EQ 2017-05-23      502.35      504.00
# 7             7  MINDTREE     EQ 2017-05-24      501.15      502.00
# 8             8  MINDTREE     EQ 2017-05-25      509.95      513.70
# 9             9  MINDTREE     EQ 2017-05-26      543.90      540.00
# 10           10  MINDTREE     EQ 2017-05-29      535.20      532.50
# 11           11  MINDTREE     EQ 2017-05-30      530.55      530.55
# 12           12  MINDTREE     EQ 2017-05-31      537.40      540.00
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# Symbol                            object
# Series                            object
# Date                      datetime64[ns]
# Prev Close                       float64
# Open Price                       float64
# High Price                       float64
# Low Price                        float64
# Last Price                       float64
# Close Price                      float64
# Average Price                    float64
# Total_Traded_Quantity              int64
# Turnover                         float64
# No. of Trades                      int64
# Deliverable Qty                    int64
# % Dly Qt to Traded Qty           float64
# year                               int64
# month                              int64
# Day_Perc_Change                  float64
# Trend                             object
# dtype: object

# %%
df.index = df.Date

# %%
df
# Out:
#             Unnamed: 0    Symbol Series       Date  Prev Close  Open Price  \
# Date
# 2017-05-15           0  MINDTREE     EQ 2017-05-15      510.60      507.35
# 2017-05-16           1  MINDTREE     EQ 2017-05-16      509.45      507.00
# 2017-05-17           2  MINDTREE     EQ 2017-05-17      511.30      507.05
# 2017-05-18           3  MINDTREE     EQ 2017-05-18      506.35      502.00
# 2017-05-19           4  MINDTREE     EQ 2017-05-19      492.90      491.95
# 2017-05-22           5  MINDTREE     EQ 2017-05-22      497.50      499.95
# 2017-05-23           6  MINDTREE     EQ 2017-05-23      502.35      504.00
# 2017-05-24           7  MINDTREE     EQ 2017-05-24      501.15      502.00
# 2017-05-25           8  MINDTREE     EQ 2017-05-25      509.95      513.70
# 2017-05-26           9  MINDTREE     EQ 2017-05-26      543.90      540.00
# 2017-05-29          10  MINDTREE     EQ 2017-05-29      535.20      532.50
# ...

# %%
plt.rcParams['figure.figsize'] = (20,10)
plt.plot(df['Date'], df['Close Price'])

# %% [markdown]
# ### Query 2.2

# %%
plt.stem(df['Date'], df['Day_Perc_Change'])
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### query 2.3

# %%
y = df['Total_Traded_Quantity']/10000000
plt.plot(df['Date'],y)

# %%
fig=plt.figure(figsize=(20,10))
plt.plot(df.index,df['Total_Traded_Quantity']/1000000,color='blue')

plt.stem(df.index, df['Day_Perc_Change'])
plt.show()

# %%
y.max()
# Out:
# 13.1335426

# %%
y
# Out:
# Date
# 2017-05-15    0.076103
# 2017-05-16    0.134637
# 2017-05-17    0.226804
# 2017-05-18    0.201463
# 2017-05-19    0.203132
# 2017-05-22    0.277269
# 2017-05-23    0.381122
# 2017-05-24    0.313439
# 2017-05-25    0.728798
# 2017-05-26    0.191846
# 2017-05-29    0.388754
# 2017-05-30    0.127359
# 2017-05-31    0.361353
# 2017-06-01    0.250597
# 2017-06-02    0.133435
# 2017-06-05    0.356372
# 2017-06-06    0.253796
# 2017-06-07    0.161011
# 2017-06-08    0.110770
# 2017-06-09    0.154542
# 2017-06-12    0.166076
# 2017-06-13    0.186396
# 2017-06-14    0.131748
# 2017-06-15    0.236954
# 2017-06-16    0.269998
# 2017-06-19    0.216389
# 2017-06-20    0.133140
# 2017-06-21    0.238898
# 2017-06-22    0.112067
# 2017-06-23    0.215658
#                 ...
# 2019-03-27    0.283168
# 2019-03-28    0.175267
# 2019-03-29    0.174310
# 2019-04-01    0.155609
# 2019-04-02    0.166009
# 2019-04-03    0.197173
# 2019-04-04    0.133990
# 2019-04-05    0.103443
# ...

# %% [markdown]
# ### Query 2.4

# %%
pieLabels = sorted(df.Trend.unique())
pctTrend = df.groupby('Trend').size()/df.shape[0]
pctTrend = pctTrend*100

# %%
pctTrend.shape
# Out:
# (9,)

# %%
pctTrend
# Out:
# Trend
# Among top gainers       6.072874
# Among top losers        3.036437
# Bear drop               0.404858
# Bull run                1.214575
# Negative               23.076923
# Positive               19.635628
# Slight Positive         9.109312
# Slight negative         8.704453
# Slight or No change    28.744939
# dtype: float64

# %%
sorted(pieLabels)
# Out:
# ['Among top gainers',
#  'Among top losers',
#  'Bear drop',
#  'Bull run',
#  'Negative',
#  'Positive',
#  'Slight Positive',
#  'Slight negative',
#  'Slight or No change']

# %%
figureObject, axesObject = plt.subplots()

axesObject.pie(pctTrend,labels=pieLabels,autopct='%.1f%%',startangle=90, wedgeprops = {'linewidth': 5})
axesObject.axis('equal')
plt.show()

# %%
dfbar =df.groupby('Trend').Total_Traded_Quantity.agg(['mean','median'])
dfbar.plot.bar(subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3f300c34e0>,
# ...
#       dtype=object)

# %% [markdown]
# ### Query 2.5

# %%
df.Day_Perc_Change.hist(bins=50,figsize=(20,10))
plt.show()
print(df.Day_Perc_Change.describe())
# Out:
# count    494.000000
# mean       0.155466
# std        2.148983
# min      -16.774886
# 25%       -1.040910
# 50%        0.046968
# 75%        1.084026
# max        9.612529
# Name: Day_Perc_Change, dtype: float64

# %% [markdown]
# ### Query 2.6

# %%
df1 = pd.read_csv('DHFL.csv')
df2 = pd.read_csv('FORTIS.csv')
df3 = pd.read_csv('MARUTI.csv')
df4 = pd.read_csv('PNB.csv')
df5 = pd.read_csv('TATAPOWER.csv')
df6 = pd.read_csv('Nifty50.csv')

# %%
df1 = df1[df1['Series'] == 'EQ']
df2 = df2[df2['Series'] == 'EQ']
df3 = df3[df3['Series'] == 'EQ']
df4 = df4[df4['Series'] == 'EQ']
df5 = df5[df5['Series'] == 'EQ']

# %%
df1.reset_index(drop = True, inplace = True)
df2.reset_index(drop = True, inplace = True)
df3.reset_index(drop = True, inplace = True)
df4.reset_index(drop = True, inplace = True)
df5.reset_index(drop = True, inplace = True)

# %%
comp = pd.concat([df1['Close Price'],df2['Close Price'],df3['Close Price'],df4['Close Price'],df5['Close Price']], axis = 1)

# %%
comp
# Out:
#      Close Price  Close Price  Close Price  Close Price  Close Price
# 0         431.40       205.25      6823.90       166.80        83.55
# 1         424.45       207.90      6953.95       174.15        83.85
# 2         429.00       205.90      6958.20       165.05        85.35
# 3         417.95       196.85      6831.05       158.50        83.75
# 4         404.20       203.55      6790.55       155.20        84.15
# 5         404.00       194.80      6701.70       150.95        82.05
# 6         402.00       196.55      6878.85       149.75        80.50
# 7         395.55       194.35      6869.65       147.45        80.25
# 8         405.50       202.55      6985.70       150.70        80.40
# 9         410.65       202.75      7064.80       150.65        81.05
# 10        410.95       196.10      7134.45       145.10        81.15
# 11        412.15       198.15      7147.50       146.35        82.40
# 12        416.65       195.15      7211.00       150.50        81.00
# ...

# %%
comp.columns = ['DHFL','FORTIS','MARUTI','PNB','TATAPOWER']

# %%
comp
# Out:
#        DHFL  FORTIS   MARUTI     PNB  TATAPOWER
# 0    431.40  205.25  6823.90  166.80      83.55
# 1    424.45  207.90  6953.95  174.15      83.85
# 2    429.00  205.90  6958.20  165.05      85.35
# 3    417.95  196.85  6831.05  158.50      83.75
# 4    404.20  203.55  6790.55  155.20      84.15
# 5    404.00  194.80  6701.70  150.95      82.05
# 6    402.00  196.55  6878.85  149.75      80.50
# 7    395.55  194.35  6869.65  147.45      80.25
# 8    405.50  202.55  6985.70  150.70      80.40
# 9    410.65  202.75  7064.80  150.65      81.05
# 10   410.95  196.10  7134.45  145.10      81.15
# 11   412.15  198.15  7147.50  146.35      82.40
# 12   416.65  195.15  7211.00  150.50      81.00
# 13   416.90  198.35  7146.60  151.90      80.70
# 14   414.25  192.95  7114.70  153.05      81.05
# 15   430.75  194.90  7125.70  153.80      81.00
# 16   424.60  191.05  7112.10  149.50      79.60
# 17   431.45  194.05  7205.70  152.35      80.00
# 18   434.45  192.95  7249.50  151.30      79.05
# ...

# %%
comp = comp.pct_change()

# %%
import seaborn as sns; sns.set(style = 'ticks', color_codes=True)
comp.dropna(inplace =True)
sns.pairplot(comp)

# %% [markdown]
# ### Query 2.7

# %%
pb = comp['DHFL'].rolling(7).std()*np.sqrt(7)
pb.plot(figsize = (20,10))

# %% [markdown]
# ### Query 2.8

# %%
dfN = pd.read_csv('./Nifty50.csv')
dfP = pd.read_csv('./DHFL.csv')

dfP = dfP[dfP['Series'] == 'EQ']
dfP.reset_index(drop = True, inplace = True)
vnp = pd.concat([dfN['Close'],dfP['Close Price']], axis = 1)

vnp.columns = ['Nifty', 'DHFL']
vnp.pct_change()
vnp.dropna(inplace =True,axis =0)

# %%
v = vnp[['Nifty','DHFL']].rolling(7).std()*np.sqrt(7)
v.plot(figsize = (20,10))

# %% [markdown]
# ### Query 2.9

# %%
points = pd.DataFrame(index = df.index)
points['p'] = np.zeros(points.shape[0])
points['sma21'] = df['Close Price'].rolling(window=21,min_periods=1).mean()
points['sma34'] = df['Close Price'].rolling(window=34,min_periods=1).mean()

fig = plt.figure(figsize = (20,10))
ax1 = fig.add_subplot(111, ylabel='Price in Rupees')
df['Close Price'].plot(ax = ax1, color = 'r')
points[['sma21','sma34']].plot(ax = ax1)

# %%
points['p'][21:] = np.where(points['sma21'][21:]>points['sma34'][21:],1.0,0.0)
points['position'] = points['p'].diff()

fig = plt.figure(figsize = (20,10))
ax1 = fig.add_subplot(111, ylabel='Price in Rupees')
df['Close Price'].plot(ax = ax1, color = 'r',lw = 2.)
points[['sma21','sma34']].plot(ax = ax1, lw = 1.)
ax1.plot(points.loc[points.position == 1.0].index, points['sma21'][points.position == 1.0],'^',markersize = 10, color = 'g')
ax1.plot(points.loc[points.position == -1.0].index, points['sma21'][points.position == -1.0],'v',markersize = 10, color = 'k')

# %% [markdown]
# ### Query 2.10

# %%
avg = df['Close Price'].rolling(14).mean()
sd = df['Close Price'].rolling(14).std()
upperBand = avg + (sd*2)
lowerBand = avg - (sd*2)

df['avg'] = np.round(avg,3)
df['upper'] = np.round(upperBand,3)
df['lower'] = np.round(lowerBand,3)

# %%
df['Average Price'].plot(c = 'k', figsize = (20,10), lw = 2)
df['avg'].plot(c='b', figsize = (20,10), lw = 1)
df['upper'].plot(c='g', figsize = (20,10), lw = 1)
df['lower'].plot(c='r', figsize = (20,10), lw = 1)

# %%
df.to_csv('week3.csv')
